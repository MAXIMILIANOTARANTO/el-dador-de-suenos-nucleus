# %% [markdown]
# # 🚀 Base de Ejecución Técnica - Núcleo del Dador de Sueños
#
# Notebook base para prototipar agentes con **memoria persistente** y **multi-modelo** (Claude, Gemini, ChatGPT).

# %%
# Instalar dependencias
# !pip install langgraph mem0ai litellm langchain python-dotenv -q

# %% [markdown]
# ## 1. Configurar API Keys (usa Secrets en Colab)

# %%
import os
from google.colab import userdata

os.environ['ANTHROPIC_API_KEY'] = userdata.get('ANTHROPIC_API_KEY')  # Claude
os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')        # Gemini
os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')        # ChatGPT

# %% [markdown]
# ## 2. Probar Model Router (multi-modelo)

# %%
from base_agent.model_router import get_model_response

respuesta = get_model_response("Hola, ¿quién eres?", model="claude-3-5-sonnet-20241022")
print(respuesta)
